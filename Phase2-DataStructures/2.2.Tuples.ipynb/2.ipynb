# %% [markdown]
# ## Tuples
# # Introduction
# - Tuples are ordered collections of items that are immutable.They are similar to lists,but their immutability makes them different.
#
# - A tuple is a collection of items, just like a list,but with one important difference:
# - Tuples are immutable (cannot be changed after creation)
# - Tuples are versatile and useful in many real-world scenarios where an immutable and ordered collection of items is required.They are commonly used in data Structures,function arguments & return values, and as dictionary keys.Understanding how to leverage tuples effectively can improve the efficiency and readability of your python code.

# %%
## Creating a Tuple
empty_tuple=()
print(empty_tuple)
print(type(empty_tuple))
# Out:
# ()
# <class 'tuple'>

# %%
lst=list()
print(type(lst))
# Out:
# <class 'list'>

# %%
tpl=tuple()
print(type(tpl))
# Out:
# <class 'tuple'>

# %%
numbers= tuple([1,2,3,4,5,6])
numbers
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
list((1,2,3,4,5,6))
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
mixed_tuple=(1,"Hello world",3.14,True)
print(mixed_tuple)
# Out:
# (1, 'Hello world', 3.14, True)

# %%
## Accessing Tuple Elements
numbers
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
print(numbers[2])
# Out:
# 3

# %%
numbers[0:4]
# Out:
# (1, 2, 3, 4)

# %%
numbers[::-1]
# Out:
# (6, 5, 4, 3, 2, 1)

# %%
## Tuple Operations 
concatenation_tuple= numbers + mixed_tuple
print(concatenation_tuple)
# Out:
# (1, 2, 3, 4, 5, 6, 1, 'Hello world', 3.14, True)

# %%
mixed_tuple * 3
# Out:
# (1,
#  'Hello world',
#  3.14,
#  True,
#  1,
#  'Hello world',
#  3.14,
#  True,
#  1,
#  'Hello world',
#  3.14,
#  True)

# %%
numbers*3
# Out:
# (1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6)

# %%
##Immutable Nature of Tuples
## Tuples are immutable ,meaning their elements cannot be chnaged
lst=[1,2,3,4,5]
print(lst)
lst[1]="Albert"
print(lst)
# Out:
# [1, 2, 3, 4, 5]
# [1, 'Albert', 3, 4, 5]

# %%
numbers[1]="guru govindi"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 numbers[1]="guru govindi"
#
# TypeError: 'tuple' object does not support item assignment

# %%
##Tuple methods
print(numbers.count(1))
print(numbers.index(3))#returns the first index of the value
# Out:
# 1
# 2

# %%
## packing and unpacking tuples
## packing
packed_tuple=1,"Hello",3.14
print(packed_tuple)
# Out:
# (1, 'Hello', 3.14)

# %%
##Unpacking a tuple 
a,b,c = packed_tuple
print(a)
print(b)
print(c)
# Out:
# 1
# Hello
# 3.14

# %%
##unpacking with * 
numbers=(1,2,3,4,5,6)
first,*middle,last=numbers
print(first)
print(middle)
print(last)
# Out:
# 1
# [2, 3, 4, 5]
# 6

# %%
##Nested Tuple
##Nested List
lst=[[1,2,3,4],[6,7,8,9],[1,"Hello",3.14,"c"]]
lst[0][0:3]
# Out:
# [1, 2, 3]

# %%
nested_tuple=((1,2,3),("a","b","c"),(True,False))
##Access the elements inside a tuple
print(nested_tuple[0])
print(nested_tuple[1][2])
# Out:
# (1, 2, 3)
# c

# %%
#iterating over nested tuples
for sub_tuple in nested_tuple:
    for item in sub_tuple:
        print(item,end=" ")
        print()
# Out:
# 1
# 2
# 3
# a
# b
# c
# True
# False
