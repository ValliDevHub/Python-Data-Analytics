# %%
##String and stringMethods
# import osprint(os.listdir())
name = "vihana  "
# print(name[0])
# print(name[1])
# print(name[2])
# print(name[3])
# print(name[4])
# print(name[5])
# print(name[6]) IndexError: string index out of range

poem = '''
In the heart of a seed 
buried deep,so deep,
A dear little plant 
lay fast asleep
'''
# print(poem)
print(len(name))
print(name.lower())
print(name.upper)
print(len(name.strip()))
# print(poem[0])
print(name.replace("vi","sa"))
print(name.isalpha())
print(name.isnumeric())
print(name[0:3])
print(name[1:3])
print(name[1:-1]) #is same as name[1:(-1 +len(name))] or
#name[1:4]
print(name[1:4])
# Out:
# 8
# vihana
# <built-in method upper of str object at 0x000002AD058406F0>
# 6
# sahana
# False
# False
# vih

# %%
#fStri
name = input("whats ur name:")
work= input("where do you work:")
live = input("where do you live?:")
#Vihana works at codewithme and lives at dubai
# print(name+"work at"+work+"and lives in"+live)
print(f"{name} works at {work} and lives at {live}")
# Out:
# alex works at alex and lives at alex
