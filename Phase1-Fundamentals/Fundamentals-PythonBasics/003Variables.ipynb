# %% [markdown]
#  ## Introduction to Variables
# - Declaring and Assigning Variables
# - Naming Conventions
# - Understanding Variable Types
# - Type Checking and Conversion
# - Dynamic Typing

# %% [markdown]
# ## Variables
# variables are fundamental elements in programming used to store data that can be referenced and manipulated
# in a program.In python,variables are created when you assign a value to them, and they dont need explicit declaration
# to reserve memory space. the declaration happens automatically when you assign a value to a variable.

# %%
a=100

# %%
## Declaring and Assigning Variables
age =30
height=5.3
name="john"
is_Student=True
## Printing the variables
print("age:",age)
print("height",height)
print("Name",name)
# Out:
# age: 30
# height 5.3
# Name john

# %%
##Naming Conventions 
'''
Varible name should be descriptive 
They must start with a letter or an '_' and contain letter,numbers and underscores
Variables names are case sensitive
''' 
# valid variable names
first_name="tony"
last_name="alexender"

#Invalid variable names 
#2age=30
first_name="geetha"
@name = "alex"
# Out:
#   Cell In[24], line 14
#     @name = "alex"
#      ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
##Understanding variable types
##Python is dynamically typed,i.e type of a variable is determined at runtime 
age=25
height=5.32
name="vani" #str
is_Student=True#boolean
print (type(age))
print (type(height))
print (type(name))
print (type(is_Student))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
## Type checking and type Conversion
print (type(height))
# Out:
# <class 'float'>

# %%
age=25
print(type(age))
#Type Conversion 
age_str=str(age)
print(age_str)
print(type(age_str))
# Out:
# <class 'int'>
# 25
# <class 'str'>

# %%
## different types of type conversion 
age='25'
print(type(int(age)))
# Out:
# <class 'int'>

# %%
name='mosh'
print(type(int(name)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 name='mosh'
# ----> 2 print(type(int(name)))
#
# ValueError: invalid literal for int() with base 10: 'mosh'

# %%
height=5.5
print(type(height))
# Out:
# <class 'float'>

# %%
print(type(int(height)))
# Out:
# <class 'int'>

# %%
float(int(height))
# Out:
# 5.0

# %%
##Dynamic Typing
##Python allows the type of a variable to change as the program executes
var=10
print(var,type(var))
var='Hello'
print(var,type(var))
var=3.14
print(var,type(var))
# Out:
# 10 <class 'int'>
# Hello <class 'str'>
# 3.14 <class 'float'>

# %%
##input
age=input("what is the age")
##print ("Enter your age",age)
print ("Enter your age",type(age))
# Out:
# Enter your age <class 'str'>
